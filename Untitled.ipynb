# %%
import os
from shubow_tools import *
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
path = r'/media/spl/D/MicroCT data/4th batch bone mets loading study/Registration week 2/418 week 2 left registered'
imgs = imreadseq_multithread(path,sitkimg = False)

# %%
import sys
print(sys.getsizeof(imgs)/1024/1024)
# Out:
# 68.69720840454102

# %%
print(imgs.shape)
# Out:
# (301, 539, 444)

# %%
imgs2 = imgs[:,200:-200,150:-150]

# %%
from shubow_tools import imsaveseq

# %%
#imsaveseq(imgs2,os.path.join(path,"shubo_VOI"),"c",sitkimages = False)
sitk.WriteImage(sitk.GetImageFromArray(imgs2),os.path.join(path,"img.nii"))

# %%
print(sys.getsizeof(imgs2)/1024/1024)

# %%
help(sitk.WriteImage)

# %%
img2 = auto_crop(imgs)
print(img2.shape)
plt.figure()
plt.set_cmap('inferno')
plt.imshow(img2.max(axis=0))
# Out:
# (301, 471, 430)

# %%
recon = imreadseq_multithread('/media/spl/D/MicroCT data/4th batch bone mets loading study/Reconstruction week 0/418 week 0 _Rec', sitkimg = False, rmbckgrd = 65)

# %%
recon.shape
# Out:
# (2610, 948, 2508)

# %%
x_mid = int(recon.shape[2]/2)
left = recon[:,:,:x_mid]
right = recon[:,:,x_mid:]

# %%
left=auto_crop(Rotate_by_Euler_angles(left))
right = auto_crop(Rotate_by_Euler_angles(right))

# %%
plt.figure()
plt.set_cmap('inferno')
plt.imshow(left.max(axis=1))

# %%
plt.figure()
plt.plot(range(left.shape[0]),left.mean(axis=(1,2)))

# %%
z_index_splt=np.argmin((left.mean(axis=(1,2)))[1500:2100])+1500
z_index_splt
# Out:
# 1584

# %%
plt.figure()
plt.imshow(left[z_index_splt])

# %%
plt.figure()
plt.plot(range(left.shape[0]),right.mean(axis=(1,2)))

# %%
z_index_splt=np.argmin((right.mean(axis=(1,2)))[1200:1800])+1200
plt.figure()
plt.imshow(right[z_index_splt:].mean(axis=0))

# %%
import pickle
path = r'/media/spl/D/MicroCT data/'
pkl_file = open(path+"serialized_recon.pkl",'wb')
# %time pickle.dump(left,pkl_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# KeyboardInterrupt:

# %%
pickle.dump(left,pkl_file)

# %%
a=pickle.load(open(path+"serialized_recon.pkl","rb"))

# %%
a.shape
# Out:
# (2610, 948, 1468)

# %%
imgs.max(axis = 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-be3c17c896b1> in <module>
# ----> 1 imgs.hist()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'
